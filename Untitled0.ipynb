# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df_url_clean = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Buyuk_Veri/Dataset/url_dataset_clean.csv')
df_email_clean = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Buyuk_Veri/Dataset/email_dataset_clean.csv')
df_sms_clean = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Buyuk_Veri/Dataset/sms_dataset_clean.csv')

try:
    df_url_clean = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Buyuk_Veri/Dataset/url_dataset_clean.csv')
    df_email_clean = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Buyuk_Veri/Dataset/email_dataset_clean.csv')
    df_sms_clean = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Buyuk_Veri/Dataset/sms_dataset_clean.csv')
    print("✅ Temizlenmiş URL, E-posta ve SMS veri setleri başarıyla yüklendi.")
except Exception as e:
    print(f"❌ Veri setleri yüklenirken hata oluştu: {e}. Lütfen dosyaların yollarını ve adlarını kontrol edin.")
    print("Önceki Colab kod bloklarını çalıştırdığınızdan emin olun.")
    exit()

print(df_url_clean.columns)
print(df_email_clean.columns)
print(df_sms_clean.columns)

phishing_url_count = df_url_clean[df_url_clean['Label'] == 1].shape[0]
phishing_email_count = df_email_clean[df_email_clean['label'] == 1].shape[0]
phishing_sms_count = df_sms_clean[df_sms_clean['label'] == 1].shape[0]


data = {
    'Attack_Vector': ['URL Phishing', 'Email Phishing', 'SMS Phishing'],
    'Attack_Count': [phishing_url_count, phishing_email_count, phishing_sms_count]
}
df_combined_vectors = pd.DataFrame(data)

print("\nBirleşik Saldırı Vektörleri Sayıları:")
print(df_combined_vectors)


output_path_combined_vectors = '/content/drive/MyDrive/Colab Notebooks/Buyuk_Veri/Dataset/combined_attack_vectors.csv'
df_combined_vectors.to_csv(output_path_combined_vectors, index=False)
print(f"\n✅ Birleşik saldırı vektörleri verisi başarıyla kaydedildi: {output_path_combined_vectors}")
# Out:
# ✅ Temizlenmiş URL, E-posta ve SMS veri setleri başarıyla yüklendi.
# Index(['LengthOfURL', 'URLComplexity', 'CharacterComplexity',
#        'DomainLengthOfURL', 'IsDomainIP', 'TLDLength', 'LetterCntInURL',
#        'URLLetterRatio', 'DigitCntInURL', 'URLDigitRatio', 'EqualCharCntInURL',
#        'QuesMarkCntInURL', 'AmpCharCntInURL', 'OtherSpclCharCntInURL',
#        'URLOtherSpclCharRatio', 'NumberOfHashtags', 'NumberOfSubdomains',
#        'HavingPath', 'PathLength', 'HavingQuery', 'HavingFragment',
#        'HavingAnchor', 'HasSSL', 'IsUnreachable', 'LineOfCode',
#        'LongestLineLength', 'HasTitle', 'HasFavicon', 'HasRobotsBlocked',
#        'IsResponsive', 'IsURLRedirects', 'IsSelfRedirects', 'HasDescription',
#        'HasPopup', 'HasIFrame', 'IsFormSubmitExternal', 'HasSocialMediaPage',
#        'HasSubmitButton', 'HasHiddenFields', 'HasPasswordFields',
#        'HasBankingKey', 'HasPaymentKey', 'HasCryptoKey',
# ...
